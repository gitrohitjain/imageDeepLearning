# %%
# !pip install pytesseract
# Out:
# Processing c:\users\jainrohi\appdata\local\pip\cache\wheels\be\c9\54\c3a5693600be95ece493b981ae104c94e1a2c4d3e434438810\pytesseract-0.3.6-py2.py3-none-any.whl
# Requirement already satisfied: Pillow in c:\programdata\anaconda3\lib\site-packages (from pytesseract) (7.2.0)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.6
# WARNING: You are using pip version 20.1.1; however, version 20.2.3 is available.
# You should consider upgrading via the 'C:\ProgramData\Anaconda3\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# ![OCR_WorkFlow.png](attachment:OCR_WorkFlow.png)

# %%
#Importing the libraries
import cv2
import pytesseract
from PIL import Image

# %% [markdown]
# ![1.png](attachment:1.png)

# %%
# Specifying the path
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# Reading the image 
image = cv2.imread('1.png')

# Extraction of text from image
text = pytesseract.image_to_string(image)

# Printing the text
print(text)
# Out:
# attitude
# is a little thing
#
# that makes
# a
#
# Big Difference

# %%
text.split()
# Out:
# ['attitude',
#  'is',
#  'a',
#  'little',
#  'thing',
#  'that',
#  'makes',
#  'a',
#  'Big',
#  'Difference']

# %%
# Create the voice_text variable to store the data.

voice_text = ""

# Pre-processing the data

for i in text.split():
    voice_text += i + ' '

voice_text = voice_text.strip() #remove leading and trailing spaces
print(voice_text)
# Out:
# attitude is a little thing that makes a Big Difference

# %%
from gtts import gTTS
from playsound import playsound

tts = gTTS(voice_text)
tts.save("test3.mp3")
playsound("test3.mp3")
